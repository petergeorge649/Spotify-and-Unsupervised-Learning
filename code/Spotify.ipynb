# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
import pandas as pd

# %%
client_id = getpass.getpass('client_id')
client_secret = getpass.getpass('client_secret')
# Out:
# client_id········
# client_secret········

# %%
# connect to the API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="a3fd2d56e9c34b1eb9847f19c74bc457",
                                                          client_secret="f4bd85f398b84b13b46b3ee85dec0f1c"))

# %%
results = sp.search(q="Lady Gaga", limit=50)

# %%
results = sp.search(q="Lady Gaga", limit=50)

# %%
type(results)
# Out:
# dict

# %%
results.keys()

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
# ...

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['tracks']['href']
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
# ...

# %%
results["tracks"]['limit']
# Out:
# 50

# %%
results['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results['tracks']['offset']
# Out:
# 0

# %%
results['tracks']['previous']

# %%
results['tracks']['total']
# Out:
# 6999

# %% [markdown]
# # let's explore Items

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
# for first song:
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['album']['id']
# Out:
# '6rePArBMb5nLWEaY9aQqL4'

# %%
results['tracks']['items'][0]['album']['name']
# Out:
# 'The Fame Monster (Deluxe Edition)'

# %%
results['tracks']['items'][0]['album']['release_date']
# Out:
# '2009-11-05'

# %%
results['tracks']['items'][0]['album']['total_tracks']
# Out:
# 23

# %%
# more info of the first song

# %%
results['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['id']
# Out:
# '0SiywuOBRcynK0uKGWdCnn'

# %%
results['tracks']['items'][0]['name']
# Out:
# 'Bad Romance'

# %%
results['tracks']['items'][0]['popularity']
# Out:
# 81

# %%
results['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# # Activity 2

# %%
my_track = results["tracks"]["items"][0]

# %%
my_track['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
get_artists_ids_from_track(results["tracks"]["items"][0])
# Out:
# ['1HY2Jd0NmPuamShAr6KMms']

# %% [markdown]
# # Playlists!

# %% [markdown]
# Categories > get all the playlists(IDs) in that category > get all the songs(IDs) from all playlists (together with their audio feature) with their ID'S.

# %% [markdown]
# Playlist link: https://open.spotify.com/playlist/75GeX247deNdTX7zdyZDnU?si=b5f4bbf165b847ec
#
# From that this is the ID:75GeX247deNdTX7zdyZDnU

# %%
playlist = sp.user_playlist_tracks("patrickimoh", "75GeX247deNdTX7zdyZDnU")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(playlist['items'])
# Out:
# 100

# %% [markdown]
# Overall is to have artist, title, id, accousticness, dancability

# %% [markdown]
# Target: Get all the ID's for all the songs in that playlist!

# %%
# let's get the ID for only one song first!
playlist['items'][0]['track']['id']

# here i make it work for the whole playlist
for item in playlist['items']:
    print(item['track']['id'])

nigeriantop100 = []
for item in playlist['items']:
    nigeriantop100.append(item['track']['id'])
# Out:
# 15NVnnLI5oXQSw10lKrR51
# 7MQ2FWFVuim1L1O3wXjkdZ
# 1H2IEdM9irHOk4YTQTgRxE
# 2Jy4EdqIZswDZvVDh5dx3A
# 4vLY6fJQWgBzQYHzguDZme
# 5FG7Tl93LdH117jEKYl3Cm
# 3ku51L937DfBoNcU9hmDQy
# 0qFhAo95HuSnwgtwa8PVTe
# 7yFtiLTGiNfCinV8j0EItD
# 42ksa1gP6QjQo12FUd0C1H
# 7b3991NnMDhwZRq7C2Cpgc
# 7rhsXamb92uzkfHG3s9Ziz
# 1a075hExjtlhASbtEnRoxF
# 5GFm1OmVhA9xNy2ZbH8yWq
# 2tB9OFgAHjAds3cqquLlvp
# 1cEhrSF6EylAEqdhUGuNpX
# 6HidGH3rmgyk47386l4p37
# 1Gm3jwEy0cx0souTcRGEby
# 0CSjeunTxJ7hrePnWvdGJe
# 28qXHN4aeQ3D2asjK0Vouz
# 4ghRDR6c8VNISdVTCQ5FK4
# 1IZGMPe57hATuLJgmMR4eP
# 4iJyoBOLtHqaGxP12qzhQI
# 10VDogAStlffCRrqkNONtR
# 2KfKuJ3iWLYu8M1srzG2h0
# 7Gw4dZ3yM7BZJqovKwEVoC
# 5suOUHDyRxvWDYF5GA6dly
# 07QIUaVKS54iMDnheYBo8F
# 1EJIcDYXwSqipW5dFe4uJz
# 51mLQ3w7yR7vjdSTFLWaY5
# 45zDhnvuFI7Jt3BTbBsWAU
# 5azcf1g5AMWfRMieQC9nZ7
# 5OypcrFg58e4k2iYHi69ED
# 6RZkc81rXdia84g2fkRutr
# 2W8T5vBoBnubizngclDq43
# 09x588yzcrz6IvqEUN2xMV
# 53PewZvhksjF9EynzsBnAR
# 4c7UBMrX7NC9QHtZQCQKBn
# 2yVi4LkOsEpJ8YvoLlpCtX
# 3QO1m6i0nsrp8aOnapvbkx
# ...

# %%
nigeriantop100
# Out:
# ['15NVnnLI5oXQSw10lKrR51',
#  '7MQ2FWFVuim1L1O3wXjkdZ',
#  '1H2IEdM9irHOk4YTQTgRxE',
#  '2Jy4EdqIZswDZvVDh5dx3A',
#  '4vLY6fJQWgBzQYHzguDZme',
#  '5FG7Tl93LdH117jEKYl3Cm',
#  '3ku51L937DfBoNcU9hmDQy',
#  '0qFhAo95HuSnwgtwa8PVTe',
#  '7yFtiLTGiNfCinV8j0EItD',
#  '42ksa1gP6QjQo12FUd0C1H',
#  '7b3991NnMDhwZRq7C2Cpgc',
#  '7rhsXamb92uzkfHG3s9Ziz',
#  '1a075hExjtlhASbtEnRoxF',
#  '5GFm1OmVhA9xNy2ZbH8yWq',
#  '2tB9OFgAHjAds3cqquLlvp',
#  '1cEhrSF6EylAEqdhUGuNpX',
#  '6HidGH3rmgyk47386l4p37',
#  '1Gm3jwEy0cx0souTcRGEby',
#  '0CSjeunTxJ7hrePnWvdGJe',
#  '28qXHN4aeQ3D2asjK0Vouz',
#  '4ghRDR6c8VNISdVTCQ5FK4',
#  '1IZGMPe57hATuLJgmMR4eP',
#  '4iJyoBOLtHqaGxP12qzhQI',
#  '10VDogAStlffCRrqkNONtR',
#  '2KfKuJ3iWLYu8M1srzG2h0',
#  '7Gw4dZ3yM7BZJqovKwEVoC',
#  '5suOUHDyRxvWDYF5GA6dly',
#  '07QIUaVKS54iMDnheYBo8F',
#  '1EJIcDYXwSqipW5dFe4uJz',
#  '51mLQ3w7yR7vjdSTFLWaY5',
#  '45zDhnvuFI7Jt3BTbBsWAU',
#  '5azcf1g5AMWfRMieQC9nZ7',
#  '5OypcrFg58e4k2iYHi69ED',
#  '6RZkc81rXdia84g2fkRutr',
# ...

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=nigeriantop100)
# Out:
# [{'danceability': 0.866,
#   'energy': 0.805,
#   'key': 9,
#   'loudness': -4.029,
#   'mode': 1,
#   'speechiness': 0.128,
#   'acousticness': 0.0466,
#   'instrumentalness': 0,
#   'liveness': 0.0196,
#   'valence': 0.496,
#   'tempo': 102.971,
#   'type': 'audio_features',
#   'id': '15NVnnLI5oXQSw10lKrR51',
#   'uri': 'spotify:track:15NVnnLI5oXQSw10lKrR51',
#   'track_href': 'https://api.spotify.com/v1/tracks/15NVnnLI5oXQSw10lKrR51',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15NVnnLI5oXQSw10lKrR51',
#   'duration_ms': 153786,
#   'time_signature': 4},
#  {'danceability': 0.658,
#   'energy': 0.466,
#   'key': 1,
#   'loudness': -5.837,
#   'mode': 0,
#   'speechiness': 0.384,
#   'acousticness': 0.0685,
#   'instrumentalness': 0.00016,
#   'liveness': 0.0803,
#   'valence': 0.732,
#   'tempo': 132.532,
#   'type': 'audio_features',
#   'id': '7MQ2FWFVuim1L1O3wXjkdZ',
#   'uri': 'spotify:track:7MQ2FWFVuim1L1O3wXjkdZ',
# ...

# %%
audio_features_nigeria = pd.DataFrame(sp.audio_features(tracks=nigeriantop100))

# %%
audio_features_nigeria.head(100)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.866   0.805    9    -4.029     1       0.1280        0.0466
# 1          0.658   0.466    1    -5.837     0       0.3840        0.0685
# 2          0.828   0.921    1    -2.971     1       0.1430        0.2260
# 3          0.561   0.722    4    -6.437     0       0.0680        0.1730
# 4          0.543   0.482    1    -5.927     1       0.0526        0.2860
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.937   0.797    2    -4.768     0       0.2060        0.0733
# 96         0.828   0.764    7    -4.938     1       0.0725        0.0400
# 97         0.883   0.674   11    -8.043     0       0.3570        0.2100
# 98         0.754   0.805    1    -6.696     1       0.4070        0.3200
# 99         0.498   0.571    5    -5.338     0       0.1010        0.0381
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
ls
# Out:
# 8_05_api_wrappers_lecture.ipynb        gnod_1st_prototype.jpg
# 8_05_api_wrappers_lecture_final.ipynb  gnod_2nd_prototype.jpg
# Spotify.ipynb
